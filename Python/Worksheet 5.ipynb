# %% [markdown]
# #Data Handling (Worksheet - 3.3)

# %% [markdown]
# 1 - Write a program to  display float number with 2 decimal places using print()
#
# e.g : Display 458.541315 as 458.54

# %%
#write your code here

# %%
n = 458.541315
round(n,2)
# Out:
# 458.54

# %%
x=45.77777
round(x,2)
# Out:
# 45.78

# %% [markdown]
# 2. Mr Sharma has invested Rs. 27,500 in 200 shares of XYZ co. ltd and 52,500 in 250 shares of ABC co. ltd. Write a program to calculate the average investment cost per share.

# %%
#write your code here.

# %%
a=float(input("enter cost of 200 shares"))
b=float(input("enter cost of 250 shares"))
c=a+b
x=200
y=250
z=x+y
print("Average investment per share",c/z)
# Out:
# enter cost of 200 shares27500
# enter cost of 250 shares52500
# Average investment per share 177.77777777777777

# %%
xyz_cst = 27,500
abc_cst = 52,500
xyz_share = 200
abc_share = 250
total_cst = xyz_cst + abc_cst
total_share = xyz_share + abc_share
cps = (total_cst) /(total_share) 
print("The cost per share is ",cps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-85a153c9febe> in <cell line: 7>()
#       5 total_cst = xyz_cst + abc_cst
#       6 total_share = xyz_share + abc_share
# ----> 7 cps = (total_cst) /(total_share)
#       8 print("The cost per share is ",cps)
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'int'

# %% [markdown]
# 3 - Write a program given 2 strings, s1 and s2, create a new string by appending s2 in the middle of s1.
#
# e.g :
#
# inputs  :
# s1 = "Ault"
# s2 = "Kelly"
#
# ouput : AuKellylt

# %%
s1="Fazil"
s2="Raju"
m=int(len(s1)/2) 
print(s1[:m]+s2+s1[m:])
# Out:
# FaRajuzil

# %%
s1="owais"
s2="ahmad"
m=int(len(s1)/2)
print(s1[:m]+s2+s1[m:])
# Out:
# owahmadais

# %% [markdown]
# 4 - Write a program to given two strings s1 and s2 return a new string made of the first and last character of input strings.
#
# Hint:-
#
# inputs : s1 = "America"
# s2 = "Japan"
#
# output : AJan

# %%
s1 = "America"
s2 = "Japan"
print(s1[0]+s2[0]+s1[-1]+s2[-1])

# %%
s1="pakistan"
s2="india"
print(s1[0]+s2[0]+s1[-1]+s2[-1])
# Out:
# pina

# %% [markdown]
# 5 - Write a program to arrange string characters into lowercase letters.
#
# e.g :
# input : str1 = PyThon
#
# output : python

# %%
str1="ENGLISH"
print(str1.lower())
# Out:
# english

# %%
str1 = "PyThon"
print(str1.lower())

# %% [markdown]
# 6 - Write a Python program to display the current date and time.

# %%
from datetime import datetime

# %%
now = datetime.now()
print(now)
# Out:
# 2023-06-01 04:53:06.994107

# %%
from datetime import datetime
now = datetime.now()
print(now)
# Out:
# 2023-06-01 04:56:13.601773

# %% [markdown]
# 7 - Write a Python program which accepts the user's first and last name and print them in reverse order with a space between them.

# %%
#write your code here.

# %%
fn = input("Enter your first name: ")
print(fn[::-1])
# Out:
# Enter your first name: Fax
# xaF

# %%
fn="owais"
fl="dar"
print(fn[::-1],fl[::-1])
# Out:
# siawo rad

# %% [markdown]
# 8 - Write a Python program to find out square of user input.

# %%
#write your code here.

# %%
5**2

# %%
2**2
# Out:
# 4

# %% [markdown]
# 9 - Write a program  an int n, return True if it is within 10 of 100 or 200. Note: abs(num) computes the absolute value of a number.

# %%
#write your code here.

# %%
n = int(input("Enter the integer: "))
print(abs(100-n) <= 10 or abs(200 - n) <=10)
# Out:
# Enter the integer: 180
# False

# %%
n=int(input("enter a number"))
print(abs(100-n)<=10 or abs(200-n)<=10)
# Out:
# enter a number195
# True

# %% [markdown]
# 10 - Write a program to given a three-digit integer (i.e. an integer from 100 to 999). Find the sum of its digits and print the result.
#
# e.g : Input :
# 476
#
# Output :
# 17

# %%
#write your code here.

# %%
n=int(input("enter 3dig inter")) 
x=int(n[0])+int(n[1])+int(n[2])
print(x)
# Out:
# enter 3dig inter123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-6ba44b3ce3e9> in <cell line: 2>()
#       1 n=int(input("enter 3dig inter"))
# ----> 2 x=int(n[0])+int(n[1])+int(n[2])
#       3 print(x)
#
# TypeError: 'int' object is not subscriptable

# %%
n = input("Enter the integer: ")
x = int(n[0]) + int(n[1]) + int(n[2])
print(x)
# Out:
# Enter the integer: 345
# 12

# %%
x = input("enter a three digit number")
y = int(x[0])+int(x[1])+int(x[2])
print(y)
# Out:
# enter a three digit number555
# 15

# %% [markdown]
# Visit [Jobaajlearnings.com ](http://learnings.jobaaj.com/)for more Courses<br><br>
# Connect with Us on <br>
#
#
# *  [Instagram](https://www.instagram.com/jobaaj.com_/)<br>
# *  [LinkedIn](https://www.linkedin.com/showcase/jobaaj-learnings/)<br>
# *  [Medium](https://jobaaj-com.medium.com/)<br>
#
# Connect with the Instructor on <br>
#
#
# *  [Instagram](https://www.instagram.com/shivavashishtha_/)<br>
# *  [LinkedIn](https://www.linkedin.com/in/shivavashishtha/)<br>
# *  [Medium](https://medium.com/@shiva.vashishtha)<br>
# *  [GitHub](https://github.com/shivavashishtha)<br>
