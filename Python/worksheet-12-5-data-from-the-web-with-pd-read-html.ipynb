# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Fixing the url from where we want to fetch the data
url="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(PPP)"

# %%
# Simply fetch the html data using read_html
df1 = pd.read_html(url)

# %%
# Let's have a look at the data we have got
df1
# Out:
# [                                                   0
#  0  Largest economies in the world by PPP GDP in 2...,
#                             Country (or territory)    Region  IMF[1][5]  \
#                             Country (or territory)    Region   Forecast
#  0                                           World         —  174471283
#  1                                           China      Asia   33014998
#  2                                   United States  Americas   26854599
#  3                                           India      Asia   13033443
#  4                                           Japan      Asia    6456527
#  ..                                            ...       ...        ...
#  224                                        Tuvalu   Oceania         63
#  225                             Wallis and Futuna   Oceania          —
#  226  Saint Helena, Ascension and Tristan da Cunha    Africa          —
# ...

# %%
# Dosen't look like a dataframe to me, let's check the type 
type(df1)
# Out:
# list

# %%
df1[0]
# Out:
#                                                    0
# 0  Largest economies in the world by PPP GDP in 2...

# %%
# Alright, It is fetched as a List, let's fetch using indexing
df1[1]
# Out:
#                            Country (or territory)    Region  IMF[1][5]  \
#                            Country (or territory)    Region   Forecast
# 0                                           World         —  174471283
# 1                                           China      Asia   33014998
# 2                                   United States  Americas   26854599
# 3                                           India      Asia   13033443
# 4                                           Japan      Asia    6456527
# ..                                            ...       ...        ...
# 224                                        Tuvalu   Oceania         63
# 225                             Wallis and Futuna   Oceania          —
# 226  Saint Helena, Ascension and Tristan da Cunha    Africa          —
# 227                                          Niue   Oceania          —
# 228                                       Tokelau   Oceania          —
#
# ...

# %%
# We have got the right dataframe at index 1
# Let's create a new dataframe using that index
df = df1[1]

# %%
# Checking the dataframe again
df
# Out:
#                            Country (or territory)    Region  IMF[1][5]  \
#                            Country (or territory)    Region   Forecast
# 0                                           World         —  174471283
# 1                                           China      Asia   33014998
# 2                                   United States  Americas   26854599
# 3                                           India      Asia   13033443
# 4                                           Japan      Asia    6456527
# ..                                            ...       ...        ...
# 224                                        Tuvalu   Oceania         63
# 225                             Wallis and Futuna   Oceania          —
# 226  Saint Helena, Ascension and Tristan da Cunha    Africa          —
# 227                                          Niue   Oceania          —
# 228                                       Tokelau   Oceania          —
#
# ...

# %%
# Checking the shape
df.shape
# Out:
# (229, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 8 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   (Country (or territory), Country (or territory))  229 non-null    object
#  1   (Region, Region)                                  229 non-null    object
#  2   (IMF[1][5], Forecast)                             229 non-null    object
#  3   (IMF[1][5], Year)                                 229 non-null    object
#  4   (World Bank[6], Estimate)                         229 non-null    object
#  5   (World Bank[6], Year)                             229 non-null    object
#  6   (CIA[7][8][9], Estimate)                          229 non-null    int64
#  7   (CIA[7][8][9], Year)                              229 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 14.4+ KB

# %%
df.isnull().sum()
# Out:
# Country (or territory)  Country (or territory)    0
# Region                  Region                    0
# IMF[1][5]               Forecast                  0
#                         Year                      0
# World Bank[6]           Estimate                  0
#                         Year                      0
# CIA[7][8][9]            Estimate                  0
#                         Year                      0
# dtype: int64
