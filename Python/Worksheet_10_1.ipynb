# %% [markdown]
# # **Pandas Series**

# %%
# Import pandas and numpy
import numpy as np
import pandas as pd

# %%
# Search for a new dataset using google dataset search
# Import the dataset
df = pd.read_csv("/content/drive/MyDrive/Project/Practice set/India COVID-19 Status")

# %%
# Get the head()
df.head()
# Out:
#    StateCode                   State Name  Active Cases (Yesterday)  \
# 0         35  Andaman and Nicobar Islands                         7
# 1         28               Andhra Pradesh                       139
# 2         12            Arunachal Pradesh                         4
# 3         18                        Assam                      2562
# 4         10                        Bihar                        98
#
#    Positive Cases (Yesterday)  Cured Cases (Yesterday)  \
# 0                       10737                    10601
# 1                     2338949                  2324077
# 2                       66879                    66579
# 3                      746059                   735462
# 4                      851214                   838814
#
#    Death Cases (Yesterday)  Active Cases (Today)  Positive Cases (Today)  \
# 0                      129                     9                   10740
# 1                    14733                   129                 2338961
# ...

# %%
# Get the info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   StateCode                   36 non-null     int64
#  1   State Name                  36 non-null     object
#  2   Active Cases (Yesterday)    36 non-null     int64
#  3   Positive Cases (Yesterday)  36 non-null     int64
#  4   Cured Cases (Yesterday)     36 non-null     int64
#  5   Death Cases (Yesterday)     36 non-null     int64
#  6   Active Cases (Today)        36 non-null     int64
#  7   Positive Cases (Today)      36 non-null     int64
#  8   Cured Cases (Today)         36 non-null     int64
#  9   Death Cases (Today)         36 non-null     int64
#  10  Last Updated (IST)          36 non-null     object
# dtypes: int64(9), object(2)
# memory usage: 3.2+ KB

# %%
# Get one of the columns using square brackets
df["StateCode"]
# Out:
# 0     35
# 1     28
# 2     12
# 3     18
# 4     10
# 5      4
# 6     22
# 7     26
# 8      7
# 9     30
# 10    24
# 11     6
# 12     2
# 13     1
# 14    20
# 15    29
# 16    32
# 17    37
# 18    31
# 19    23
# 20    27
# 21    14
# 22    17
# 23    15
# 24    13
# 25    21
# 26    34
# 27     3
# 28     8
# 29    11
# 30    33
# 31    36
# 32    16
# 33     5
# 34     9
# 35    19
# Name: StateCode, dtype: int64

# %%
# Check the type of the output
type(df["StateCode"])
# Out:
# pandas.core.series.Series

# %%
# Assign the pandas series to a variable
state_code = df["StateCode"]

# %%
# Check all the attributes and methods available for the Dataframe using dirt()
dir(state_code)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
# Apply the methouds we have for pandas DataPrames
# Show the head()
state_code.head()
# Out:
# 0    35
# 1    28
# 2    12
# 3    18
# 4    10
# Name: StateCode, dtype: int64

# %%
# Show the tail()
state_code.tail()
# Out:
# 31    36
# 32    16
# 33     5
# 34     9
# 35    19
# Name: StateCode, dtype: int64

# %%
# Check datatype
state_code.dtypes
# Out:
# dtype('int64')

# %%
# Show thw info()
state_code.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36 entries, 0 to 35
# Series name: StateCode
# Non-Null Count  Dtype
# --------------  -----
# 36 non-null     int64
# dtypes: int64(1)
# memory usage: 416.0 bytes

# %%
# Check the shape
state_code.shape
# Out:
# (36,)

# %%
# Check the length using in-built function len()
len(state_code)
# Out:
# 36

# %%
# Check index
state_code.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
# Show describe()
state_code.describe()
# Out:
# count    36.000000
# mean     18.833333
# std      10.929645
# min       1.000000
# 25%       9.750000
# 50%      18.500000
# 75%      28.250000
# max      37.000000
# Name: StateCode, dtype: float64
