# %%
# Import the library
import pandas as pd

# %%
# Get the data
df = pd.read_csv("/content/drive/MyDrive/Project/Practice set/India COVID-19 Status")

# %%
# Check the head()
df.head()
# Out:
#    StateCode                   State Name  Active Cases (Yesterday)  \
# 0         35  Andaman and Nicobar Islands                         7
# 1         28               Andhra Pradesh                       139
# 2         12            Arunachal Pradesh                         4
# 3         18                        Assam                      2562
# 4         10                        Bihar                        98
#
#    Positive Cases (Yesterday)  Cured Cases (Yesterday)  \
# 0                       10737                    10601
# 1                     2338949                  2324077
# 2                       66879                    66579
# 3                      746059                   735462
# 4                      851214                   838814
#
#    Death Cases (Yesterday)  Active Cases (Today)  Positive Cases (Today)  \
# 0                      129                     9                   10740
# 1                    14733                   129                 2338961
# ...

# %%
# Assign a variable for one of the columns
st = df.StateCode

# %%
# Check the head of the series
st.head()
# Out:
# 0    35
# 1    28
# 2    12
# 3    18
# 4    10
# Name: StateCode, dtype: int64

# %%
# Changing one of the data from the series using .iloc[]
st.iloc[2]=455
# Out:
# <ipython-input-6-f85ba5798741>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st.iloc[2]=455

# %%
df
# Out:
#     StateCode                                State Name  \
# 0          35               Andaman and Nicobar Islands
# 1          28                            Andhra Pradesh
# 2         455                         Arunachal Pradesh
# 3          18                                     Assam
# 4          10                                     Bihar
# 5           4                                Chandigarh
# 6          22                              Chhattisgarh
# 7          26  Dadra and Nagar Haveli and Daman and Diu
# 8           7                                     Delhi
# 9          30                                      Goa*
# 10         24                                   Gujarat
# 11          6                                   Haryana
# 12          2                          Himachal Pradesh
# 13          1                         Jammu and Kashmir
# 14         20                                 Jharkhand
# 15         29                                 Karnataka
# ...

# %%
# To avoid the corruption of the data assign a copy of the series which will make it completely independent
st1 = df.StateCode.copy()

# %%
st1.iloc[2]= 55

# %%
st1
# Out:
# 0     35
# 1     28
# 2     55
# 3     18
# 4     10
# 5      4
# 6     22
# 7     26
# 8      7
# 9     30
# 10    24
# 11     6
# 12     2
# 13     1
# 14    20
# 15    29
# 16    32
# 17    37
# 18    31
# 19    23
# 20    27
# 21    14
# 22    17
# 23    15
# 24    13
# 25    21
# 26    34
# 27     3
# 28     8
# 29    11
# 30    33
# 31    36
# 32    16
# 33     5
# 34     9
# 35    19
# Name: StateCode, dtype: int64

# %%
df
# Out:
#     StateCode                                State Name  \
# 0          35               Andaman and Nicobar Islands
# 1          28                            Andhra Pradesh
# 2         455                         Arunachal Pradesh
# 3          18                                     Assam
# 4          10                                     Bihar
# 5           4                                Chandigarh
# 6          22                              Chhattisgarh
# 7          26  Dadra and Nagar Haveli and Daman and Diu
# 8           7                                     Delhi
# 9          30                                      Goa*
# 10         24                                   Gujarat
# 11          6                                   Haryana
# 12          2                          Himachal Pradesh
# 13          1                         Jammu and Kashmir
# 14         20                                 Jharkhand
# 15         29                                 Karnataka
# ...
