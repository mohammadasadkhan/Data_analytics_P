# %%
# Import the library
import pandas as pd

# %%
# Read the csv data file
df = pd.read_csv("/content/drive/MyDrive/Project/Practice set/RELIANCE.NS.csv")
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2022-09-05  2531.000000  2581.500000  2531.000000  2569.800049
# 1    2022-09-06  2573.000000  2606.000000  2572.000000  2596.850098
# 2    2022-09-07  2575.000000  2594.899902  2570.000000  2581.750000
# 3    2022-09-08  2588.250000  2598.000000  2571.000000  2585.399902
# 4    2022-09-09  2610.000000  2610.000000  2564.000000  2569.300049
# ..          ...          ...          ...          ...          ...
# 244  2023-08-29  2452.050049  2453.449951  2408.149902  2420.350098
# 245  2023-08-30  2432.000000  2443.000000  2415.000000  2418.050049
# 246  2023-08-31  2423.000000  2425.000000  2399.899902  2407.000000
# 247  2023-09-01  2406.550049  2425.649902  2401.649902  2412.649902
# 248  2023-09-04  2412.649902  2423.649902  2405.300049  2410.699951
#
#        Adj Close    Volume
# 0    2560.754395   5227785
# 1    2587.709229   5030172
# 2    2572.662109   3455942
# 3    2576.299316   3256840
# ...

# %%
# Printing the head
df.head()
# Out:
#          Date     Open         High     Low        Close    Adj Close   Volume
# 0  2022-09-05  2531.00  2581.500000  2531.0  2569.800049  2560.754395  5227785
# 1  2022-09-06  2573.00  2606.000000  2572.0  2596.850098  2587.709229  5030172
# 2  2022-09-07  2575.00  2594.899902  2570.0  2581.750000  2572.662109  3455942
# 3  2022-09-08  2588.25  2598.000000  2571.0  2585.399902  2576.299316  3256840
# 4  2022-09-09  2610.00  2610.000000  2564.0  2569.300049  2560.256104  3837302

# %%
# Select one column using square brackets
df['Date']
# Out:
# 0      2022-09-05
# 1      2022-09-06
# 2      2022-09-07
# 3      2022-09-08
# 4      2022-09-09
#           ...
# 244    2023-08-29
# 245    2023-08-30
# 246    2023-08-31
# 247    2023-09-01
# 248    2023-09-04
# Name: Date, Length: 249, dtype: object

# %%
# Checking type of the given result
type(df['Date'])
# Out:
# pandas.core.series.Series

# %%
# Printing DataFrame instead of a Series using double square brackets
df[['Date']]
# Out:
#            Date
# 0    2022-09-05
# 1    2022-09-06
# 2    2022-09-07
# 3    2022-09-08
# 4    2022-09-09
# ..          ...
# 244  2023-08-29
# 245  2023-08-30
# 246  2023-08-31
# 247  2023-09-01
# 248  2023-09-04
#
# [249 rows x 1 columns]

# %%
type(df[['Date']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Printing 2 Columns DataFrame using double square brackets
df[['Date','Open']]
# Out:
#            Date         Open
# 0    2022-09-05  2531.000000
# 1    2022-09-06  2573.000000
# 2    2022-09-07  2575.000000
# 3    2022-09-08  2588.250000
# 4    2022-09-09  2610.000000
# ..          ...          ...
# 244  2023-08-29  2452.050049
# 245  2023-08-30  2432.000000
# 246  2023-08-31  2423.000000
# 247  2023-09-01  2406.550049
# 248  2023-09-04  2412.649902
#
# [249 rows x 2 columns]

# %%
df['Date','Open']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Date', 'Open')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Printing 3 Columns DataFrame using double square brackets
df[['Date','Open','Volume']]
# Out:
#            Date         Open    Volume
# 0    2022-09-05  2531.000000   5227785
# 1    2022-09-06  2573.000000   5030172
# 2    2022-09-07  2575.000000   3455942
# 3    2022-09-08  2588.250000   3256840
# 4    2022-09-09  2610.000000   3837302
# ..          ...          ...       ...
# 244  2023-08-29  2452.050049   8438322
# 245  2023-08-30  2432.000000   6084473
# 246  2023-08-31  2423.000000  10819300
# 247  2023-09-01  2406.550049   9056421
# 248  2023-09-04  2412.649902   4671325
#
# [249 rows x 3 columns]

# %%
# Fetching one of the columns using pandas attribute
df.Volume
# Out:
# 0       5227785
# 1       5030172
# 2       3455942
# 3       3256840
# 4       3837302
#          ...
# 244     8438322
# 245     6084473
# 246    10819300
# 247     9056421
# 248     4671325
# Name: Volume, Length: 249, dtype: int64

# %%
# Checking if both the series are equal using .equals attribute of pandas
df.Volume.equals(df['Volume'])
# Out:
# True
