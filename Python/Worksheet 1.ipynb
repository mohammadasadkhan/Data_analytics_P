# %% [markdown]
# # Welcome to Worksheet 2.1 Let's Start Coding......!

# %% [markdown]
# Question 1 - Write a program which can take the user's name and print a greeting message along with the name.

# %%
n=input("Enter your name ")
print("Hello....!",n)
# Out:
# Enter your name Shiva
# Hello....! Shiva

# %%
n=input("enter your name":)
print("hello....!",n)
# Out:
#   File "<ipython-input-2-ed1598bd5009>", line 1
#     n=input("enter your name":)
#                              ^
# SyntaxError: invalid syntax

# %%
n=input("Enter your name ")
print("Hello...!",n)
# Out:
# Enter your name susil kumar patra
# Hello...! susil kumar patra

# %% [markdown]
# Question 2 - Let's try to play with numbers, take two numbers as input and print their sum along with a message.

# %%
a=int(input("Enter first number "))
b=int(input("Enter Second number "))
sum=a+b
print("The sum is ",sum)
# Out:
# Enter first number 34
# Enter Second number 43
# The sum is  77

# %%
a=int(input("Enter your first number "))
b=int(input("Enter your second number "))
c=a+b
print("the sum is",c)
# Out:
# Enter your first number 7
# Enter your second number 6
# the sum is 13

# %% [markdown]
# Question 3 - Okay let's level up the numbers game, input length and breadth of a rectangle from the user and calculate it's area.

# %%
l=int(input("Enter the length"))
b=int(input("Enter the breadth "))
a=2*(l+b)
print("The area is ",a)
# Out:
# Enter the length23
# Enter the breadth 32
# The area is  110

# %%
l=int(input("Enter your length "))
b=int(input("Enter your breath "))
a=l*b
print("the area is",a)
# Out:
# Enter your length 5
# Enter your breath 3
# the area is 15

# %% [markdown]
# Question 4 - Whoa! you are becoming a pro now. Let's see if you could solve this one.<br> Input a number and print it's cube.<br>
# Quite Simple but can you write multiple solutions for this.

# %%
z=int(input("Enter a number "))
cube = z*z*z
print("The cube is ",cube)
# Out:
# Enter a number 3
# The cube is  27

# %%
a=int(input("Enter your  number "))
c=a**3
print("the cube is",c)
# Out:
# Enter your  number 3
# the cube is 27

# %% [markdown]
# Question 5 - Write a program to input a number 'n' and print it's Square and Cube.

# %%
n=int(input("Enter a number"))
square=n*n
cube=n*n*n
print("The square is ",square)
print("The cube is ",cube)
# Out:
# Enter a number3
# The square is  9
# The cube is  27

# %%
a=int(input("Enter your  number "))
b=a**2
c=a**3
print("the square is",b)
print("the cube is",c)
# Out:
# Enter your  number 2
# the square is 4
# the cube is 8

# %% [markdown]
# Question 6 - Write a program to input values in Km and convert it into miles.<br> (1Km = 0.621371 Miles)

# %%
k=float(input("Enter the distance in Km "))
m=  0.621371*k
print("The distance in Miles would be ",m)
# Out:
# Enter the distance in Km 999.78
# The distance in Miles would be  621.23429838

# %%
k=int(input("Enter your distance "))
m=k*0.621371
print("the distance in miles",m)
# Out:
# Enter your distance 5
# the distance in miles 3.106855

# %% [markdown]
# Quetion 7 - Write a program to input in Quintals and convert it into Grams and Kilograms.

# %%
q=float(input("Enter the value in Quintal"))
k=q*100
g=q*100000
print("The value in Grams would be ",g)
print("The value in Kg would be ",k)
# Out:
# Enter the value in Quintal776.89
# The value in Grams would be  77689000.0
# The value in Kg would be  77689.0

# %%
q=int(input("Enter the value in quintal "))
1q=100kg
1q=100000gm
print("the value of gram",1q)
print("the valu of kg",1q)
# Out:
#   File "<ipython-input-9-52f873275a39>", line 2
#     1q=100kg
#      ^
# SyntaxError: invalid syntax

# %%
q=int(input("Enter the value in quintal "))
k=q*100
g=q*100000
print("the value of kg",k)
print 
("the value of ",g)
# Out:
# Enter the value in quintal 25
# the value of kg 2500
# ('the value of ', 2500000)

# %% [markdown]
# Quetion 8 - Write a program to input two numbers and swape them with each other.

# %%
a=int(input("enter the first value"))
b=int(input("enter the second value"))
print("The value of a now is ",a)
print("The value of b now is",b)
a,b=b,a
print("The value of a now is ",a)
print("The value of b now is",b)
# Out:
# enter the first value7
# enter the second value98
# The value of a now is  7
# The value of b now is 98
# The value of a now is  98
# The value of b now is 7

# %%
a=int(input("Enter your first number "))
b=int(input("Enter your second number "))
a,b=b,a
print("the value of a now is",a)
print("the value of b now is",b)
# Out:
# Enter your first number 7
# Enter your second number 98
# the value of a now is 98
# the value of b now is 7

# %% [markdown]
# Question 9 - Write a program to input three numbers and swap them as this:<br> First number becomes second number, second number becomes third number and third number becomes the first number

# %%
a=int(input("enter the first value"))
b=int(input("enter the second value"))
c=int(input("enter the first value"))
print("The value of a now is ",a)
print("The value of b now is",b)
print("The value of c now is ",c)
a,b,c=b,c,a
print("The value of a now is ",a)
print("The value of b now is",b)
print("The value of c now is ",c)
# Out:
# enter the first value14
# enter the second value25
# enter the first value36
# The value of a now is  14
# The value of b now is 25
# The value of c now is  36
# The value of a now is  25
# The value of b now is 36
# The value of c now is  14

# %% [markdown]
# Question 10 - Write a program to inout three numbers and swap them as this:<br>
# 1st number gets the value of 1st+2nd<br>
# 2nd number gets the value of 1st+3rd<br>
# 3rd number gets the value of 3rd+2nd<br>

# %%
a=int(input("enter the first value"))
b=int(input("enter the second value"))
c=int(input("enter the first value"))
print("The value of a now is ",a)
print("The value of b now is",b)
print("The value of c now is ",c)
a,b,c=a+b,a+c,c+b
print("The value of a now is ",a)
print("The value of b now is",b)
print("The value of c now is ",c)
# Out:
# enter the first value23
# enter the second value34
# enter the first value45
# The value of a now is  23
# The value of b now is 34
# The value of c now is  45
# The value of a now is  57
# The value of b now is 68
# The value of c now is  79

# %%
a=int(input("Enter your first value "))
b=int(input("Enter your second value "))
c=int(input("Enter your third value "))
print("the value of a now is",a)
print("the value of b now is",b)
print("the value of c now is ",c)
a,b,c=a+b,a+c,a+b
print("the value of a now is",a)
print("the value of b now is",b)
print("the value of c now is",c)
# Out:
# Enter your first value 23
# Enter your second value 34
# Enter your third value 45
# the value of a now is 23
# the value of b now is 34
# the value of c now is  45
# the value of a now is 57
# the value of b now is 68
# the value of c now is 57

# %% [markdown]
# Visit [Jobaajlearnings.com ](http://learnings.jobaaj.com/)for more Courses<br><br>
# Connect with Us on <br>
#
#
# *  [Instagram](https://www.instagram.com/jobaaj.com_/)<br>
# *  [LinkedIn](https://www.linkedin.com/showcase/jobaaj-learnings/)<br>
# *  [Medium](https://jobaaj-com.medium.com/)<br>
#
# Connect with the Instructor on <br>
#
#
# *  [Instagram](https://www.instagram.com/shivavashishtha_/)<br>
# *  [LinkedIn](https://www.linkedin.com/in/shivavashishtha/)<br>
# *  [Medium](https://medium.com/@shiva.vashishtha)<br>
# *  [GitHub](https://github.com/shivavashishtha)<br>
