# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/elon-musk-tweets/elonmusk_tweets.csv
# /kaggle/input/time-series-datasets/daily-minimum-temperatures-in-me.csv
# /kaggle/input/time-series-datasets/sales-of-shampoo-over-a-three-ye.csv
# /kaggle/input/time-series-datasets/Electric_Production.csv
# /kaggle/input/time-series-datasets/monthly-beer-production-in-austr.csv

# %%
df = pd.read_csv("/kaggle/input/time-series-datasets/Electric_Production.csv",parse_dates=["DATE"],index_col="DATE")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 397 entries, 1985-01-01 to 2018-01-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IPG2211A2N  397 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2 KB

# %%
df
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151
# ...                ...
# 2017-09-01     98.6154
# 2017-10-01     93.6137
# 2017-11-01     97.3359
# 2017-12-01    114.7212
# 2018-01-01    129.4048
#
# [397 rows x 1 columns]

# %%
df.plot(figsize=(15,7))
# Out:
# <Axes: xlabel='DATE'>

# %%
import matplotlib.pyplot as plt
x=df.loc["2016":"2017"]
x.plot(figsize=(15,7))
# Out:
# <Axes: xlabel='DATE'>

# %%
df1=pd.read_csv("/kaggle/input/time-series-datasets/daily-minimum-temperatures-in-me.csv")

# %%
df1.columns
# Out:
# Index(['Date', 'Daily minimum temperatures'], dtype='object')

# %%
df1["Date"]=pd.to_datetime(df1["Date"])

# %%
df1.index=df1["Date"]

# %%
df1
# Out:
#                  Date Daily minimum temperatures
# Date
# 1981-01-01 1981-01-01                       20.7
# 1981-01-02 1981-01-02                       17.9
# 1981-01-03 1981-01-03                       18.8
# 1981-01-04 1981-01-04                       14.6
# 1981-01-05 1981-01-05                       15.8
# ...               ...                        ...
# 1990-12-27 1990-12-27                         14
# 1990-12-28 1990-12-28                       13.6
# 1990-12-29 1990-12-29                       13.5
# 1990-12-30 1990-12-30                       15.7
# 1990-12-31 1990-12-31                         13
#
# [3650 rows x 2 columns]

# %%
df1.drop("Date",axis=1,inplace=True)

# %%
df1
# Out:
#            Daily minimum temperatures
# Date
# 1981-01-01                       20.7
# 1981-01-02                       17.9
# 1981-01-03                       18.8
# 1981-01-04                       14.6
# 1981-01-05                       15.8
# ...                               ...
# 1990-12-27                         14
# 1990-12-28                       13.6
# 1990-12-29                       13.5
# 1990-12-30                       15.7
# 1990-12-31                         13
#
# [3650 rows x 1 columns]

# %%
x=df1.loc["2012":"2015"]
x.plot(figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 x=df1.loc["2012":"2015"]
# ----> 2 x.plot(figsize=(15,7))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:446, in MPLPlot.generate(self)
# ...

# %%
df1.columns
# Out:
# Index(['Daily minimum temperatures'], dtype='object')

# %%
df1["Daily minimum temperatures"]=pd.to_numeric(df1["Daily minimum temperatures"],errors="coerce")

# %%
x=df1.loc["1980":"1981"]
x.plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df.loc["2015-01"]
# Out:
#             IPG2211A2N
# DATE
# 2015-01-01    120.2696

# %%
df.loc["2015-01-01"]
# Out:
# IPG2211A2N    120.2696
# Name: 2015-01-01 00:00:00, dtype: float64

# %%
df2=pd.read_csv("/kaggle/input/elon-musk-tweets/elonmusk_tweets.csv")

# %%
df2.head()
# Out:
#                    id           created_at  \
# 0  849636868052275200  2017-04-05 14:56:29
# 1  848988730585096192  2017-04-03 20:01:01
# 2  848943072423497728  2017-04-03 16:59:35
# 3  848935705057280001  2017-04-03 16:30:19
# 4  848416049573658624  2017-04-02 06:05:23
#
#                                                 text
# 0  b'And so the robots spared humanity ... https:...
# 1  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2      b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3                b'Stormy weather in Shortville ...'
# 4  b"@DaveLeeBBC @verge Coal is dying due to nat ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2819 entries, 0 to 2818
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2819 non-null   int64
#  1   created_at  2819 non-null   object
#  2   text        2819 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 66.2+ KB

# %%
df2["created_at"]=pd.to_datetime(df2["created_at"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2819 entries, 0 to 2818
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2819 non-null   int64
#  1   created_at  2819 non-null   datetime64[ns]
#  2   text        2819 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 66.2+ KB

# %%
df2.index=df2["created_at"]

# %%
df2
# Out:
#                                      id          created_at  \
# created_at
# 2017-04-05 14:56:29  849636868052275200 2017-04-05 14:56:29
# 2017-04-03 20:01:01  848988730585096192 2017-04-03 20:01:01
# 2017-04-03 16:59:35  848943072423497728 2017-04-03 16:59:35
# 2017-04-03 16:30:19  848935705057280001 2017-04-03 16:30:19
# 2017-04-02 06:05:23  848416049573658624 2017-04-02 06:05:23
# ...                                 ...                 ...
# 2011-12-03 08:22:07  142881284019060736 2011-12-03 08:22:07
# 2011-12-03 08:20:28  142880871391838208 2011-12-03 08:20:28
# 2011-12-01 10:29:04  142188458125963264 2011-12-01 10:29:04
# 2011-12-01 09:55:11  142179928203460608 2011-12-01 09:55:11
# 2010-06-04 18:31:57         15434727182 2010-06-04 18:31:57
#
#                                                                   text
# created_at
# 2017-04-05 14:56:29  b'And so the robots spared humanity ... https:...
# 2017-04-03 20:01:01  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# ...

# %%
df2.drop(["id","created_at"],axis=1,inplace=True)

# %%
df2
# Out:
#                                                                   text
# created_at
# 2017-04-05 14:56:29  b'And so the robots spared humanity ... https:...
# 2017-04-03 20:01:01  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2017-04-03 16:59:35      b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 2017-04-03 16:30:19                b'Stormy weather in Shortville ...'
# 2017-04-02 06:05:23  b"@DaveLeeBBC @verge Coal is dying due to nat ...
# ...                                                                ...
# 2011-12-03 08:22:07               b'That was a total non sequitur btw'
# 2011-12-03 08:20:28  b'Great Voltaire quote, arguably better than T...
# 2011-12-01 10:29:04  b'I made the volume on the Model S http://t.co...
# 2011-12-01 09:55:11  b"Went to Iceland on Sat to ride bumper cars o...
# 2010-06-04 18:31:57  b'Please ignore prior tweets, as that was some...
#
# [2819 rows x 1 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2819 entries, 2017-04-05 14:56:29 to 2010-06-04 18:31:57
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2819 non-null   object
# dtypes: object(1)
# memory usage: 44.0+ KB

# %%
df2.loc["2015"]
# Out:
#                                                                   text
# created_at
# 2015-12-22 18:41:22  b'RT @SpaceX: Going up and coming down. More p...
# 2015-12-22 04:57:19  b'High res video of landing from the helo http...
# 2015-12-22 04:16:36  b'RT @SpaceX: Another view of Falcon 9 first s...
# 2015-12-22 03:44:50    b'Live video from LZ-1 https://t.co/Ve6gEXfOdh'
# 2015-12-22 03:31:36  b'Falcon 9 standing on LZ-1 at Cape Canaveral ...
# ...                                                                ...
# 2015-01-06 01:43:45  b'Taking questions now at http://t.co/CpOyWeAk0G'
# 2015-01-06 00:11:18  b'Background on our attempt to land Falcon 9 r...
# 2015-01-05 19:18:07  b'Drone spaceport ship heads to its hold posit...
# 2015-01-05 17:24:48  b"Ask me anything at 9pm Florida time (focused...
# 2015-01-01 15:41:59  b"RT @SpaceX: 2014 included:\n6 Falcon 9 launc...
#
# [436 rows x 1 columns]

# %%
df2.loc["2015-05"]
# Out:
#                                                                   text
# created_at
# 2015-05-27 03:57:09  b'Air Force certifies @SpaceX to compete for l...
# 2015-05-22 08:41:00  b"What are the best riddles you've heard that ...
# 2015-05-22 08:24:49  b'Another good riddle: drill a hole thru a sph...
# 2015-05-22 02:39:41  b'Astronomer Royal Martin Rees: How soon will ...
# 2015-05-21 21:34:11  b'RT @SpaceX: Cargo is offloaded and spacecraf...
# 2015-05-19 22:04:08  b'This is not the full Gigafactory, it is just...
# 2015-05-19 06:32:15  b'Fossil fuels subsidised by $10m a minute, sa...
# 2015-05-17 15:49:20  b'RT @johngreen: My brilliant brother has a me...
# 2015-05-16 01:51:45  b'RT @SpaceX: Tired of the same old travel des...
# 2015-05-16 01:51:40  b'RT @SpaceX: Adventure awaits! Explore Mars\x...
# 2015-05-12 21:05:16                         b'@jankenbrandt Hi Julie!'
# 2015-05-12 17:14:25  b'RT @TeslaMotors: Agreed. @FTC affirms States...
# ...

# %%
df2.loc["2015-05-05"]
# Out:
#                                                                   text
# created_at
# 2015-05-05 18:27:30  b'Hold down firing of Dragon 2 spacecraft at C...
# 2015-05-05 06:36:48  b"RT @NASA: Five things to know about Wednesda...

# %%
df2.loc["2015-05-05 06"]
# Out:
#                                                                   text
# created_at
# 2015-05-05 06:36:48  b"RT @NASA: Five things to know about Wednesda...
