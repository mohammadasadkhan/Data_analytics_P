# %%
import pandas as pd

# %%
df= pd.read_excel("/kaggle/input/dirty-excel-data/Cola.xlsx")

# %%
df.head()
# Out:
#    Data provided by SimFin              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      NaN                     NaN        NaN        NaN
# 1  Profit & Loss statement                     NaN        NaN        NaN
# 2                      NaN          in million USD     FY '09     FY '10
# 3                      NaN  NET OPERATING REVENUES      30990      35119
# 4                      NaN      Cost of goods sold      11088      12693
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2     FY '11     FY '12     FY '13     FY '14     FY '15     FY '16
# 3      46542      48017      46854      45998      44294      41863
# 4      18215      19053      18421      17889      17482      16465
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2      FY '17      FY '18
# ...

# %%
df.tail()
# Out:
#     Data provided by SimFin  \
# 98                      NaN
# 99                      NaN
# 100                     NaN
# 101                     NaN
# 102                     NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 98   Effect of exchange rate changes on cash and ca...        576       -166
# 99   Cash Provided by (Used in) Investing Activitie...        NaN        NaN
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 98        -430       -255       -611       -934       -878         -6
# 99         NaN        NaN        NaN        NaN          0          0
# 100        NaN        NaN        NaN        NaN          0          0
# ...

# %%
df
# Out:
#      Data provided by SimFin  \
# 0                        NaN
# 1    Profit & Loss statement
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# ...

# %%
df1 = pd.read_excel("/kaggle/input/dirty-excel-data/Cola.xlsx",skiprows = 3, index_col="in million USD")

# %%
df1
# Out:
#                                                    Unnamed: 0 FY '09 FY '10  \
# in million USD
# NET OPERATING REVENUES                                    NaN  30990  35119
# Cost of goods sold                                        NaN  11088  12693
# Gross Profit                                              NaN  19902  22426
# Selling, general and administrative expenses              NaN  11358  13194
# Other operating charges                                   NaN    313    819
# ...                                                       ...    ...    ...
# Effect of exchange rate changes on cash and cas...        NaN    576   -166
# Cash Provided by (Used in) Investing Activities...        NaN    NaN    NaN
# Cash Provided by (Used in) Financing Activities...        NaN    NaN    NaN
# Net Cash Provided by (Used in) Discontinued Ope...        NaN    NaN    NaN
# Net increase (decrease) during the year                   NaN   2320   1496
#
# ...

# %%
df1.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df1
# Out:
#                                                    FY '09 FY '10 FY '11  \
# in million USD
# NET OPERATING REVENUES                              30990  35119  46542
# Cost of goods sold                                  11088  12693  18215
# Gross Profit                                        19902  22426  28327
# Selling, general and administrative expenses        11358  13194  17422
# Other operating charges                               313    819    732
# ...                                                   ...    ...    ...
# Effect of exchange rate changes on cash and cas...    576   -166   -430
# Cash Provided by (Used in) Investing Activities...    NaN    NaN    NaN
# Cash Provided by (Used in) Financing Activities...    NaN    NaN    NaN
# Net Cash Provided by (Used in) Discontinued Ope...    NaN    NaN    NaN
# Net increase (decrease) during the year              2320   1496   4286
#
#                                                    FY '12 FY '13 FY '14  \
# ...

# %%
df1.index.name = None

# %%
df1
# Out:
#                                                    FY '09 FY '10 FY '11  \
# NET OPERATING REVENUES                              30990  35119  46542
# Cost of goods sold                                  11088  12693  18215
# Gross Profit                                        19902  22426  28327
# Selling, general and administrative expenses        11358  13194  17422
# Other operating charges                               313    819    732
# ...                                                   ...    ...    ...
# Effect of exchange rate changes on cash and cas...    576   -166   -430
# Cash Provided by (Used in) Investing Activities...    NaN    NaN    NaN
# Cash Provided by (Used in) Financing Activities...    NaN    NaN    NaN
# Net Cash Provided by (Used in) Discontinued Ope...    NaN    NaN    NaN
# Net increase (decrease) during the year              2320   1496   4286
#
#                                                    FY '12 FY '13 FY '14  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, NET OPERATING REVENUES to Net increase (decrease) during the year
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FY '09  81 non-null     object
#  1   FY '10  81 non-null     object
#  2   FY '11  81 non-null     object
#  3   FY '12  81 non-null     object
#  4   FY '13  81 non-null     object
#  5   FY '14  81 non-null     object
#  6   FY '15  89 non-null     object
#  7   FY '16  91 non-null     object
#  8   FY '17  92 non-null     object
#  9   FY '18  92 non-null     object
# dtypes: object(10)
# memory usage: 8.6+ KB

# %%
df1.columns
# Out:
# Index(['FY '09', 'FY '10', 'FY '11', 'FY '12', 'FY '13', 'FY '14', 'FY '15',
#        'FY '16', 'FY '17', 'FY '18'],
#       dtype='object')

# %%
df1.describe()
# Out:
#         FY '09  FY '10  FY '11  FY '12  FY '13  FY '14  FY '15  FY '16  \
# count       81      81      81      81      81      81      89      91
# unique      77      77      77      77      77      78      79      78
# top          0  FY '10       0    9086       0  FY '14       0       0
# freq         2       2       2       2       2       2       6       8
#
#         FY '17  FY '18
# count       92      92
# unique      87      86
# top       1283    6476
# freq         2       2

# %%
df1.isnull().sum()
# Out:
# FY '09    19
# FY '10    19
# FY '11    19
# FY '12    19
# FY '13    19
# FY '14    19
# FY '15    11
# FY '16     9
# FY '17     8
# FY '18     8
# dtype: int64
